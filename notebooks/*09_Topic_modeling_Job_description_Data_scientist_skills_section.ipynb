# %%
# nltk.download('stopwords')
# nltk.download('wordnet')

# %%
# !python -m spacy download en_core_web_sm
# !python -m spacy download en
# !python -m spacy download en_core_web_md

# %%
import pandas as pd
import os
from bs4 import BeautifulSoup
import requests
import re
import nltk
import textcleaner
import pickle
import spacy
import jieba

from sklearn.feature_extraction.text import CountVectorizer 
from sklearn.decomposition import TruncatedSVD
from sklearn.decomposition import NMF
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.feature_extraction.text import TfidfVectorizer
from nltk.tokenize import word_tokenize, sent_tokenize
from textblob import TextBlob
import textcleaner as tc
from nltk.stem import WordNetLemmatizer 
import re
import spacy
from gensim.parsing.preprocessing import preprocess_string
from gensim import corpora, models, similarities, matutils

from src.models import display_topics

# %%
# %load_ext autoreload
# %autoreload 2

# %%
! pip install --editable ..
# Out:
# Obtaining file:///Users/greenapple/project4
# Installing collected packages: src
#   Found existing installation: src 0.1.0
#     Uninstalling src-0.1.0:
#       Successfully uninstalled src-0.1.0
#   Running setup.py develop for src
# Successfully installed src

# %% [markdown]
# ## Load data

# %%
# Load tokenized text
pickling_out = open('/Users/greenapple/project4/data/processed/jobs_skills_token.pkl', 'rb')
jobs_skills = pickle.load(pickling_out)

# %%
jobs_skills.shape
# Out:
# (8939, 20)

# %%
jobs_skills.columns
# Out:
# Index(['company_name', 'description', 'job_title', 'link', 'location',
#        'salary', 'type', 'clean_text', 'noun', 'noun_lemma', 'lemma', 'word',
#        'sentences', 'start_stop', 'skills', 'clean_skills', 'word_skills',
#        'noun_skills', 'lemma_skills', 'noun_lemma_skills'],
#       dtype='object')

# %%
# REMOVE
# Tokenize:
# jobs['noun'] = jobs['clean_text'].apply(tokenize_noun)
# jobs['noun_lemma'] = jobs['clean_text'].apply(tokenize_noun_lemma)
# jobs['lemma'] = jobs['clean_text'].apply(tokenize_lemma)
# jobs['word'] = jobs['clean_text'].apply(tokenize_word)

# %%
# Load tokenized text
pickling_out = open('/Users/greenapple/project4/data/processed/jobs_wa_ca_skills_token.pkl', 'rb')
jobs_skills = pickle.load(pickling_out)

# %%
jobs_skills.shape
# Out:
# (14158, 16)

# %% [markdown]
# ## Topic modeling

# %%
# Data scientist/analyst jobs only
jobs_skills_d = jobs_skills.loc[jobs_skills.type=='positive']
jobs_skills_d.shape, jobs_skills.shape
# Out:
# ((5058, 20), (8939, 20))

# %% [markdown]
# ### Noun as a token

# %% [markdown]
# #### TF-IDF and LSA with Noun as token

# %%
# Model name: ***noun_tf_idf_LSA_1***
# Tokenizer: noun
# Vectorizer: TF-IDF
# Dimensionality reduction: LSA

tf_idf_vc_1 = TfidfVectorizer(ngram_range=(1, 2),
                            max_df = 0.9,
                            min_df = 0.005,
                            stop_words = stop_words_1)   

components = 20  # number of LSA components
lsa_1 = TruncatedSVD(components, random_state = 5)


topics = lsa_1.fit_transform(tf_idf_vc_1.fit_transform(jobs_skills_d.noun_skills).toarray())  # reduce dimensionality

print(len(tf_idf_vc_1.vocabulary_))   # number of words in dictionary
print(lsa_1.explained_variance_ratio_)      # explained variance

# pd.DataFrame(tf_idf_vc_1.fit_transform(jobs.noun).toarray(), columns=tf_idf_vc_1.get_feature_names()).head(10)

# lsa_1.components_
# tf_idf_vc_1.get_feature_names()

noun_tf_idf_LSA_1 = display_topics.topics_to_df(lsa_1, tf_idf_vc_1.get_feature_names(), 5, 'noun_tf_idf_LSA_1')  # save topics

pd.set_option('max_colwidth', 200)  # display strings
noun_tf_idf_LSA_1
# Out:
# /Users/greenapple/anaconda3/envs/project4e/lib/python3.7/site-packages/sklearn/feature_extraction/text.py:300: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['bike', 'marketing', 'parking', 'views', 'waterfront'] not in stop_words.
#   'stop_words.' % sorted(inconsistent))
# 1949
# [0.08477922 0.10993958 0.07875003 0.06573058 0.07444977 0.07319841
#  0.06681852 0.06536558 0.04583335 0.03468844 0.03027125 0.02966191
#  0.0246457  0.02361911 0.01607748 0.01484424 0.01378042 0.0134061
#  0.00838973 0.00437378]
#                                                                                                    noun_tf_idf_LSA_1
# 0                                                         modeling, statistics, machine, stage journey, levers value
# 1                                                                  databricks, azure, warehouse, database, pipelines
# 2                                                          player, game, device play, franchises casino, game player
# 3                                                          clients, transportation, management, information, project
# 4                                 production, leverage inference, enforcement world, violets, offerings capabilities
# 5                                    processes, improvement, training running, running predictions, goal improvement
# 6                               query, judge questions, responsibility query, ambiguities engineers, information bot
# 7                                          splunk, network, splunk environments, concepts splunk, telecommunications
# 8                                energy, energy energy, modeling algorithm, energy subsidiaries, reliability support
# 9                                     documentation, software, training, training procedures, software documentation
# 10                                         machine array, marketplace goal, remodels professional, focus stage, move
# 11                                                       query, names, guidelines, users, understanding instructions
# 12  pipelines recommendations, algorithms pipelines, content delivery, marketing algorithms, recommendations content
# 13                        assurance, contract, queries knowledge, questions recommendations, configuration assurance
# 14                                                              machine, engineering, intelligence, agency, security
# 15                                                machine, engineering, machine software, software, machine language
# 16                                                             charlies, tableau, college, visualization, dashboards
# 17                                            resources, tracking systems, tracking, kaleidoscope, database tracking
# 18                                                           engineering, languages, processing, knowledge, analyses
# 19                                                                  coaching, education, knowledge, travel, analyses

# %%
words = ['modeling', 'statistics', 'machine', 'stage journey', 'levers value']
word_dict = {}
for word in words:
    word_dict[word] = tf_idf_vc_1.vocabulary_[word]
word_dict
# Out:
# {'modeling': 1088,
#  'statistics': 1676,
#  'machine': 960,
#  'stage journey': 1667,
#  'levers value': 947}

# %%
tf_idf_vc_1.get_feature_names()
# Out:
# ['abilities',
#  'abuse',
#  'abuse training',
#  'access',
#  'access databases',
#  'access offerings',
#  'access queries',
#  'accommodations',
#  'accountabilities',
#  'accountabilities owner',
#  'accounting',
#  'accounting allaspects',
#  'accuracy',
#  'accuracy machine',
#  'accuracy responsibility',
#  'achievement',
#  'achievement understanding',
#  'acquisition',
#  'acquisition engineers',
#  'acquisition understanding',
#  'action',
#  'action collaborate',
#  'action minority',
#  'activities',
#  'activities deliverables',
#  'activities instruction',
#  'activities project',
#  'activities responsibility',
#  'activities scope',
#  'activity',
#  'activity range',
#  'acumen',
#  'ad',
#  'ad degree',
#  'adaptability',
#  'adaptability recommendations',
#  'addition',
#  'additionalinformation',
#  'additionalinformation database',
#  'administration',
#  'administrativesupport',
#  'administrativesupport tracking',
#  'adoption',
#  'advice',
#  'advice collection',
#  'affiliation',
#  'affiliation pregnancy',
#  'agency',
#  'agency documentation',
#  'agency password',
#  'agency productivity',
#  'agency support',
#  'agency systems',
#  'agency understanding',
#  'aid',
#  'aid certificate',
#  'alerting',
#  'alerts',
#  'alerts apps',
#  'algorithm',
#  'algorithm kpi',
#  'algorithms',
#  'algorithms pipelines',
#  'algorithms requests',
#  'algorithms risk',
#  'allaspects',
#  'allaspects meetings',
#  'amazons',
#  'ambiguities',
#  'ambiguities engineers',
#  'ambiguities lead',
#  'ambiguity',
#  'ambiguity errors',
#  'analyses',
#  'analyze',
#  'analyze sources',
#  'ancestry',
#  'ancestry color',
#  'andarrange',
#  'andarrange translation',
#  'announcements',
#  'announcements registrations',
#  'api',
#  'api custom',
#  'applicants',
#  'applicants consideration',
#  'applicants histories',
#  'applicants resume',
#  'approach',
#  'approaches',
#  'approaches machine',
#  'approval',
#  'approval bachelors',
#  'apps',
#  'apps dashboards',
#  'apps experts',
#  'aptitude',
#  'aptitude software',
#  'architect',
#  'architect certification',
#  'architecture',
#  'architectures',
#  'architectures bigdata',
#  'area',
#  'areas',
#  'areas control',
#  'areas focus',
#  'areas lifecycle',
#  'arrangingfacility',
#  'arrangingfacility rentals',
#  'array',
#  'array text',
#  'art',
#  'art communication',
#  'assembly',
#  'assembly maintenance',
#  'assessment',
#  'assignment',
#  'assignment ambiguity',
#  'assignments',
#  'assignments deadlines',
#  'assist',
#  'assist deployment',
#  'assistance',
#  'assistance college',
#  'assistance email',
#  'assistance organization',
#  'assistance recruiting',
#  'associatesdegree',
#  'associatesdegree administrativesupport',
#  'assurance',
#  'assurance degree',
#  'assurance partners',
#  'attention',
#  'attention entry',
#  'attention guideline',
#  'attention help',
#  'attention problem',
#  'attention road',
#  'attitude',
#  'attitude player',
#  'audience',
#  'audience masters',
#  'audience relationships',
#  'audiences',
#  'audiences community',
#  'audiences information',
#  'audiences language',
#  'auditing',
#  'auditing automating',
#  'authorization',
#  'authorization charlies',
#  'automating',
#  'automating logs',
#  'automation',
#  'azure',
#  'azure databricks',
#  'azure visas',
#  'bachelors',
#  'bachelors computer',
#  'bachelors degree',
#  'bachelors emphasis',
#  'bachelors field',
#  'background',
#  'background check',
#  'background databricks',
#  'background object',
#  'background series',
#  'background systems',
#  'backgrounds',
#  'backgrounds supervision',
#  'balance',
#  'balance sheet',
#  'base',
#  'base chip',
#  'bash',
#  'bash scripting',
#  'basis',
#  'bay',
#  'bay owners',
#  'behavior',
#  'beliefs',
#  'beliefs shares',
#  'benefit',
#  'benefit offers',
#  'bigdata',
#  'bigdata mart',
#  'blend',
#  'blend entrepreneurship',
#  'bot',
#  'bot responsibility',
#  'box',
#  'box delivery',
#  'brand',
#  'brand clients',
#  'brands',
#  'brands overstock',
#  'build',
#  'build ship',
#  'businesses',
#  'businesses communications',
#  'businesses interrelationships',
#  'businesss',
#  'businesss decision',
#  'calculations',
#  'calculations reliability',
#  'call',
#  'call schedule',
#  'capabilities',
#  'capabilities leverage',
#  'capacity',
#  'capacity array',
#  'card',
#  'card security',
#  'careers',
#  'cases',
#  'casino',
#  'casino gummy',
#  'center',
#  'centers',
#  'certificate',
#  'certificate certificate',
#  'certificate harassment',
#  'certification',
#  'certification ecosystem',
#  'certification training',
#  'certifications',
#  'certifications computer',
#  'chain',
#  'challenge',
#  'challenge spirit',
#  'challenges',
#  'challenges thequality',
#  'challenges win',
#  'chance',
#  'channels',
#  'characteristic',
#  'characteristic laws',
#  'charlies',
#  'charlies compensation',
#  'charlies opportunity',
#  'charts',
#  'charts formulas',
#  'check',
#  'check state',
#  'checklists',
#  'checklists timelines',
#  'checks',
#  'checks query',
#  'checks resources',
#  'children',
#  'children partners',
#  'children shift',
#  'chip',
#  'chip world',
#  'circumstances',
#  'circumstances timelines',
#  'class',
#  'class publisher',
#  'classification',
#  'classification feature',
#  'classification regression',
#  'cleansing',
#  'cleansing integrity',
#  'clients',
#  'clients collect',
#  'clients competitors',
#  'clients interface',
#  'clients management',
#  'clients needs',
#  'clients transportation',
#  'cloud',
#  'coach',
#  'coach workplan',
#  'coaching',
#  'code',
#  'code background',
#  'code environments',
#  'collaborate',
#  'collaborate infrastructure',
#  'collaborate managers',
#  'collaborate manner',
#  'colleagues',
#  'collect',
#  'collect rider',
#  'collection',
#  'collection activities',
#  'collection entry',
#  'collection mining',
#  'collection range',
#  'collection recommendations',
#  'collection tracking',
#  'college',
#  'college qualifications',
#  'college tuition',
#  'color',
#  'color equity',
#  'color identity',
#  'color leave',
#  'color origin',
#  'command',
#  'command line',
#  'command statistics',
#  'commerce',
#  'commitment',
#  'commitment toand',
#  'communicate',
#  'communicate system',
#  'communication',
#  'communication audiences',
#  'communication countries',
#  'communication discretion',
#  'communication duties',
#  'communication excel',
#  'communication grant',
#  'communication levels',
#  'communication presentation',
#  'communication speaker',
#  'communication understanding',
#  'communication vendors',
#  'communication world',
#  'communication writing',
#  'communications',
#  'communications legacy',
#  'communications platforms',
#  'communicator',
#  'communicator recommendations',
#  'communities',
#  'communities color',
#  'communities interest',
#  'communities provider',
#  'community',
#  'community membersfunders',
#  'community networks',
#  'communitypartners',
#  'communitypartners additionalinformation',
#  'commuters',
#  'commuters support',
#  'compensation',
#  'compensation package',
#  'compete',
#  'compete device',
#  'competitors',
#  'competitors enthusiasm',
#  'compile',
#  'compile analyze',
#  'completion',
#  'complexity',
#  'compliance',
#  'compliance initiatives',
#  'computer',
#  'computer azure',
#  'computer communication',
#  'computer engineering',
#  'computer field',
#  'computer machine',
#  'computer mathematics',
#  'computer payments',
#  'computer testing',
#  'computing',
#  'concepts',
#  'concepts splunk',
#  'concise',
#  'concise way',
#  'conclusions',
#  'conclusions visualization',
#  'condition',
#  'condition affiliation',
#  'conferences',
#  'configuration',
#  'configuration assurance',
#  'connect',
#  'connect compete',
#  'connect splunk',
#  'connection',
#  'connection manyconnections',
#  'connections',
#  'connections access',
#  'connections ip',
#  'consideration',
#  'consideration ancestry',
#  'consideration color',
#  'constraints',
#  'consultant',
#  'consultant communication',
#  'consultants',
#  'consultants project',
#  'consultants track',
#  'consulting',
#  'consumer',
#  'consumer access',
#  'contact',
#  'contact line',
#  'container',
#  'container environments',
#  'content',
#  'content delivery',
#  'context',
#  'context market',
#  'context neighborhood',
#  'context project',
#  'contingency',
#  'contingency engagements',
#  'contract',
#  'contract deliverables',
#  'contract opportunity',
#  'contract project',
#  'contracts',
#  'contracts invoices',
#  'contracts security',
#  'control',
#  'control review',
#  'control understanding',
#  'conversations',
#  'conversations agency',
#  'cooking',
#  'cooking craze',
#  'coordination',
#  'coordination resources',
#  'coordination training',
#  'cost',
#  'counties',
#  'countries',
#  'countries world',
#  'country',
#  'coverage',
#  'coverage activities',
#  'craze',
#  'craze millions',
#  'creation',
#  'creation context',
#  'credibility',
#  'credibility material',
#  'cross',
#  'cross training',
#  'culture',
#  'curiosity',
#  'curiosity agency',
#  'curiosity modeling',
#  'curricula',
#  'curricula evaluation',
#  'custom',
#  'custom cleansing',
#  'cycle',
#  'dashboard',
#  'dashboard sources',
#  'dashboards',
#  'dashboards compliance',
#  'dashboards opportunity',
#  'dashboards reports',
#  'dashboards tableau',
#  'database',
#  'database background',
#  'database excel',
#  'database manufacturing',
#  'database structures',
#  'database systems',
#  'database tracking',
#  'databases',
#  'databases media',
#  'databases network',
#  'databases systems',
#  'databricks',
#  'databricks pipelines',
#  'databricks qualifications',
#  'datasets',
#  'day',
#  'day collaborate',
#  'day collection',
#  'day day',
#  'day opportunity',
#  'deadlines',
#  'deadlines communication',
#  'deadlines number',
#  'deadlines pressure',
#  'deadlines project',
#  'decision',
#  'decision game',
#  'decision purposes',
#  'decision support',
#  'decisions',
#  'decisions ad',
#  'degradation',
#  'degradation aptitude',
#  'degree',
#  'degree computer',
#  'degree field',
#  'degree focus',
#  'degree statistics',
#  'deliverables',
#  'deliverables outcomes',
#  'deliverables understanding',
#  'delivery',
#  'delivery attitude',
#  'delivery duties',
#  'delivery improvement',
#  'delivery interactions',
#  'delivery points',
#  'demand',
#  'demand dashboard',
#  'demand modeling',
#  'demands',
#  'demands needs',
#  'demeanor',
#  'demeanor subject',
#  'department',
#  'department coverage',
#  'department managers',
#  'deployment',
#  'deployment management',
#  'depth',
#  'description',
#  'description engine',
#  'description support',
#  'desire',
#  'desire leader',
#  'details',
#  'detection',
#  'detection prevention',
#  'detection systems',
#  'determination',
#  'determination request',
#  'developer',
#  'developer architect',
#  'developer understanding',
#  'developer world',
#  'developers',
#  'developers queries',
#  'device',
#  'device play',
#  'difference',
#  'direction',
#  'direction aid',
#  'direction mentorship',
#  'director',
#  'director production',
#  'disabilities',
#  'disabilities assistance',
#  'discipline',
#  'discovery',
#  'discovery model',
#  'discretion',
#  'discretion patience',
#  'diversity',
#  'diversity relevancy',
#  'division',
#  'division fortune',
#  'division qualifications',
#  'documentation',
#  'documentation communication',
#  'documentation managers',
#  'documentation training',
#  'documentation ways',
#  'documents',
#  'documents packets',
#  'documents procedures',
#  'domain',
#  'drivers',
#  'drug',
#  'drug test',
#  'duties',
#  'duties information',
#  'duties responsibilities',
#  'duties self',
#  'econometrics',
#  'econometrics command',
#  'economics',
#  'economics finance',
#  'economy',
#  'economy tuning',
#  'ecosystem',
#  'ecosystem knowledge',
#  'edge',
#  'edge machine',
#  'edge today',
#  'education',
#  'education masters',
#  'effectiveness',
#  'efficiency',
#  'efficiency acquisition',
#  'efficiency degradation',
#  'efforts',
#  'email',
#  'email communication',
#  'email communitypartners',
#  'email determination',
#  'emphasis',
#  'emphasis computer',
#  'emphasis economy',
#  'energy',
#  'energy energy',
#  'energy managers',
#  'energy subsidiaries',
#  'energy systems',
#  'enforcement',
#  'enforcement world',
#  'engagement',
#  'engagements',
#  'engagements value',
#  'engine',
#  'engine market',
#  'engineer',
#  'engineering',
#  'engineering facets',
#  'engineering information',
#  'engineering statistics',
#  'engineers',
#  'engineers direction',
#  'engineers goal',
#  'engineers innovations',
#  'engineers spectrum',
#  'engines',
#  'engines machines',
#  'enhancements',
#  'enhancements modifications',
#  'enjoy',
#  'enjoy curiosity',
#  'enterprise',
#  'enterprises',
#  'enterprises providers',
#  'enthusiasm',
#  'enthusiasm clients',
#  'entrepreneurship',
#  'entrepreneurship key',
#  'entry',
#  'entry checks',
#  'entry office',
#  'environments',
#  'environments agency',
#  'environments education',
#  'environments generation',
#  'environments monitor',
#  'environments proficient',
#  'equity',
#  'equity delivery',
#  'errors',
#  'errors review',
#  'etiquetteprofessionalism',
#  'etiquetteprofessionalism communication',
#  'evaluation',
#  'evaluation surveyincluding',
#  'evaluation training',
#  'events',
#  'excel',
#  'excel functions',
#  'excel sql',
#  'excellence',
#  'excellence management',
#  'execution',
#  'expectations',
#  'expectations box',
#  'experiences',
#  'experimentation',
#  'experimentation player',
#  'experiments',
#  'experts',
#  'experts flexibility',
#  'exploration',
#  'exploration power',
#  'expression',
#  'expression information',
#  'extraction',
#  'extraction prediction',
#  'face',
#  'face circumstances',
#  'facets',
#  'facets machine',
#  'familiarity',
#  'families',
#  'families children',
#  'feature',
#  'feature engineering',
#  'feature experimentation',
#  'features',
#  'feedback',
#  'feedback ridership',
#  'fees',
#  'fees andarrange',
#  'field',
#  'field achievement',
#  'field background',
#  'field database',
#  'field statistics',
#  'fields',
#  'finance',
#  'finance director',
#  'finance statistics',
#  'flexibility',
#  'focus',
#  'focus mathematics',
#  'focus stage',
#  'folder',
#  'folder structure',
#  'footprint',
#  'footprint millions',
#  'forecasting',
#  'forecasting simulation',
#  'form',
#  'form perks',
#  'format',
#  'format auditing',
#  'formats',
#  'formats needs',
#  'formats person',
#  'forms',
#  'forms surveys',
#  'formulas',
#  'formulas messages',
#  'fortune',
#  'fortune information',
#  'framework',
#  'framework self',
#  'frameworks',
#  'franchises',
#  'franchises casino',
#  'fraud',
#  'fraud detection',
#  'friend',
#  'friend neighbor',
#  'fulfill',
#  'fulfill requests',
#  'fulfillment',
#  'fulfillment consumer',
#  'fun',
#  'function',
#  'functions',
#  'functions database',
#  'functions knowledge',
#  'functions project',
#  'fundamentals',
#  'funder',
#  'funder databases',
#  'funders',
#  'funders partners',
#  'future',
#  'game',
#  'game franchises',
#  'game player',
#  'generation',
#  'generation businesses',
#  'goal',
#  'goal improvement',
#  'goal machine',
#  'goal types',
#  'goals',
#  'goals build',
#  'goals face',
#  'goals marketplace',
#  'government',
#  'government law',
#  'grant',
#  'grant managers',
#  'grantors',
#  'grantors areas',
#  'grants',
#  'grants contracts',
#  'grasp',
#  'grasp security',
#  'ground',
#  'groups',
#  'guidance',
#  'guidance methodologies',
#  'guideline',
#  'guideline ambiguities',
#  'guidelines',
#  'guidelines efficiency',
#  'guidelines query',
#  'guides',
#  'guides support',
#  'gummy',
#  'gummy solitaire',
#  'hadoop',
#  'hadoop pig',
#  'harassment',
#  'harassment training',
#  'healthcare',
#  'help',
#  'help guideline',
#  'help system',
#  'histories',
#  'histories assistance',
#  'history',
#  'holiday',
#  'holiday pay',
#  'hood',
#  'hood apps',
#  'hours',
#  'humilityinclusion',
#  'humilityinclusion racism',
#  'ideas',
#  'ideas outcomes',
#  'identity',
#  'identity expression',
#  'identity validation',
#  'ididata',
#  'ididata government',
#  'impacts',
#  'implementation',
#  'improvement',
#  'improvement areas',
#  'improvement network',
#  'improvement processes',
#  'improvement software',
#  'improvements',
#  'improvements challenges',
#  'improvements order',
#  'improvements practices',
#  'individual',
#  'individuals',
#  'individuals disabilities',
#  'individuals range',
#  'industries',
#  'industries supplier',
#  'inference',
#  'inference guidance',
#  'inference order',
#  'information',
#  'information authorization',
#  'information bot',
#  'information communicator',
#  'information database',
#  'information extraction',
#  'information formats',
#  'information guidelines',
#  'information improvement',
#  'information marital',
#  'information project',
#  'information providetraining',
#  'information subject',
#  'information verify',
#  'information visit',
#  'infrastructure',
#  'infrastructure discovery',
#  'infrastructure efficiency',
#  'initiatives',
#  'initiatives member',
#  'initiatives scalability',
#  'innovation',
#  'innovation opportunity',
#  'innovations',
#  'innovations production',
#  'insight',
#  'installations',
#  'installations assembly',
#  'instruction',
#  'instruction managers',
#  'instructions',
#  'instructions applicants',
#  'instructions forms',
#  'instructions judgements',
#  'insurance',
#  'insurance portability',
#  'integration',
#  'integration help',
#  'integration visualization',
#  'integrity',
#  'integrity manner',
#  'integrity reports',
#  'integrity validation',
#  'intelligence',
#  'intelligence accuracy',
#  'intelligence software',
#  'intent',
#  'intent query',
#  'interactions',
#  'interactions self',
#  'interest',
#  'interest capacity',
#  'interest communications',
#  'interface',
#  'interface commuters',
#  'internet',
#  'interpretation',
#  'interpretation funder',
#  'interpretation project',
#  'interrelationships',
#  'interrelationships resolution',
#  'intersection',
#  'intersection software',
#  'invoices',
#  'invoices coordination',
#  'ip',
#  'ip network',
#  'issue',
#  'issue resolution',
#  'journey',
#  'journey installations',
#  'journey move',
#  'judge',
#  'judge questions',
#  'judgements',
#  'judgements context',
#  'judgment',
#  'kaleidoscope',
#  'kaleidoscope phone',
#  'kaleidoscope play',
#  'key',
#  'key brand',
#  'king',
#  'king pierce',
#  'knowledge',
#  'knowledge access',
#  'knowledge power',
#  'knowledge principles',
#  'knowledge privacy',
#  'knowledge process',
#  'knowledge stores',
#  'knowledge telephony',
#  'kpi',
#  'kpi calculations',
#  'landscape',
#  'landscape stories',
#  'language',
#  'language attention',
#  'language intelligence',
#  'language learners',
#  'language mining',
#  'language processing',
#  'language python',
#  'languages',
#  'launch',
#  'launch communities',
#  'law',
#  'law enforcement',
#  'laws',
#  'laws payment',
#  'laws regulations',
#  'lead',
#  'lead assignment',
#  'leader',
#  'leader background',
#  'leaders',
#  'leaders system',
#  'leaders warehouse',
#  'leadership',
#  'leadership information',
#  'learners',
#  'learners audiences',
#  'leave',
#  'leave identity',
#  'legacy',
#  'legacy edge',
#  'levels',
#  'levels engineers',
#  'leverage',
#  'leverage inference',
#  'levers',
#  'levers value',
#  'lifecycle',
#  'lifecycle collection',
#  'line',
#  'line day',
#  'line proficiency',
#  'line trackingsystems',
#  'literature',
#  'literature collection',
#  'logs',
#  'logs azure',
#  'lookout',
#  'lookout ways',
#  'machine',
#  'machine algorithms',
#  'machine array',
#  'machine classification',
#  'machine econometrics',
#  'machine engineers',
#  'machine interest',
#  'machine knowledge',
#  'machine language',
#  'machine software',
#  'machine statistics',
#  'machines',
#  'machines users',
#  'maintain',
#  'maintain transportation',
#  'maintenance',
#  'maintenance owners',
#  'maintenance software',
#  'management',
#  'management communicate',
#  'management contract',
#  'management functions',
#  'management maintain',
#  'management offerings',
#  'management project',
#  'management qualifications',
#  'management software',
#  'management staging',
#  'management support',
#  'managers',
#  'managers activity',
#  'managers cross',
#  'managers division',
#  'managers grantors',
#  'managers managers',
#  'managers monitoring',
#  'managers organization',
#  'managers point',
#  'managers purchasing',
#  'managers range',
#  ...]

# %%
tf_idf_vc_1.vocabulary_
# Out:
# {'programming': 1364,
#  'mathematics': 1039,
#  'production': 1346,
#  'code': 275,
#  'environments': 627,
#  'generation': 738,
#  'businesses': 199,
#  'interrelationships': 875,
#  'resolution': 1509,
#  'algorithms': 61,
#  'risk': 1547,
#  'management': 978,
#  'offerings': 1144,
#  'capabilities': 208,
#  'leverage': 944,
#  'inference': 813,
#  'order': 1161,
#  'systems': 1736,
#  'pipelines': 1235,
#  'engineers': 606,
#  'innovations': 839,
#  'decisions': 480,
#  'ad': 32,
#  'degree': 484,
#  'computer': 350,
#  'machine': 960,
#  'statistics': 1676,
#  'physics': 1227,
#  'field': 678,
#  'background': 163,
#  'object': 1137,
#  'language': 912,
#  'mining': 1075,
#  'bash': 175,
#  'scripting': 1570,
#  'points': 1263,
#  'table': 1754,
#  'tennis': 1770,
#  'violets': 1891,
#  'ididata': 794,
#  'government': 748,
#  'law': 922,
#  'enforcement': 594,
#  'world': 1938,
#  'identity': 791,
#  'validation': 1876,
#  'fraud': 715,
#  'detection': 517,
#  'prevention': 1309,
#  'hood': 784,
#  'apps': 93,
#  'experts': 655,
#  'flexibility': 687,
#  'programming mathematics': 1368,
#  'mathematics production': 1042,
#  'production code': 1348,
#  'code environments': 277,
#  'environments generation': 630,
#  'generation businesses': 739,
#  'businesses interrelationships': 201,
#  'interrelationships resolution': 876,
#  'resolution algorithms': 1510,
#  'algorithms risk': 64,
#  'risk management': 1548,
#  'management offerings': 983,
#  'offerings capabilities': 1145,
#  'capabilities leverage': 209,
#  'leverage inference': 945,
#  'inference order': 815,
#  'order systems': 1164,
#  'systems pipelines': 1744,
#  'pipelines engineers': 1237,
#  'engineers innovations': 609,
#  'innovations production': 840,
#  'production systems': 1352,
#  'systems decisions': 1741,
#  'decisions ad': 481,
#  'ad degree': 33,
#  'degree computer': 485,
#  'computer machine': 355,
#  'machine statistics': 970,
#  'statistics physics': 1683,
#  'physics field': 1228,
#  'field background': 680,
#  'background object': 166,
#  'object language': 1138,
#  'language mining': 916,
#  'mining bash': 1076,
#  'bash scripting': 176,
#  'scripting points': 1572,
#  'points table': 1265,
#  'table tennis': 1755,
#  'tennis violets': 1771,
#  'violets ididata': 1892,
#  'ididata government': 795,
#  'government law': 749,
#  'law enforcement': 923,
#  'enforcement world': 595,
#  'world identity': 1942,
#  'identity validation': 793,
#  'validation fraud': 1877,
#  'fraud detection': 716,
#  'detection prevention': 518,
#  'prevention hood': 1310,
#  'hood apps': 785,
#  'apps experts': 95,
#  'experts flexibility': 656,
#  'enjoy': 615,
#  'curiosity': 436,
#  'modeling': 1088,
#  'place': 1241,
#  'interest': 866,
#  'capacity': 210,
#  'array': 110,
#  'text': 1778,
#  'classification': 259,
#  'regression': 1468,
#  'guidance': 760,
#  'methodologies': 1062,
#  'initiatives': 834,
#  'scalability': 1556,
#  'infrastructure': 831,
#  'efficiency': 578,
#  'acquisition': 17,
#  'direction': 531,
#  'mentorship': 1058,
#  'developer': 522,
#  'understanding': 1853,
#  'levers': 946,
#  'value': 1879,
#  'audience': 141,
#  'masters': 1030,
#  'econometrics': 564,
#  'command': 300,
#  'probability': 1320,
#  'theory': 1782,
#  'desire': 514,
#  'leader': 929,
#  'spark': 1641,
#  'proficiency': 1359,
#  'sql': 1662,
#  'python': 1407,
#  'range': 1437,
#  'record': 1460,
#  'goals': 744,
#  'build': 197,
#  'ship': 1607,
#  'improvement': 798,
#  'network': 1123,
#  'partners': 1201,
#  'retailers': 1536,
#  'pottery': 1281,
#  'fulfillment': 721,
#  'consumer': 389,
#  'access': 3,
#  'stage': 1666,
#  'journey': 885,
#  'installations': 842,
#  'assembly': 114,
#  'maintenance': 975,
#  'owners': 1186,
#  'proprietors': 1387,
#  'specialty': 1646,
#  'areas': 104,
#  'enjoy curiosity': 616,
#  'curiosity modeling': 438,
#  'modeling place': 1093,
#  'place mining': 1243,
#  'mining modeling': 1078,
#  'modeling machine': 1091,
#  'machine interest': 966,
#  'interest capacity': 867,
#  'capacity array': 211,
#  'array text': 111,
#  'text classification': 1779,
#  'classification regression': 261,
#  'regression inference': 1469,
#  'inference guidance': 814,
#  'guidance methodologies': 761,
#  'methodologies initiatives': 1064,
#  'initiatives scalability': 836,
#  'scalability pipelines': 1557,
#  'pipelines infrastructure': 1239,
#  'infrastructure efficiency': 833,
#  'efficiency acquisition': 579,
#  'acquisition engineers': 18,
#  'engineers direction': 607,
#  'direction mentorship': 533,
#  'mentorship developer': 1059,
#  'developer understanding': 524,
#  'understanding levers': 1860,
#  'levers value': 947,
#  'value audience': 1881,
#  'audience masters': 142,
#  'masters degree': 1032,
#  'degree statistics': 488,
#  'physics mathematics': 1229,
#  'mathematics field': 1041,
#  'field statistics': 682,
#  'statistics machine': 1680,
#  'machine econometrics': 964,
#  'econometrics command': 565,
#  'command statistics': 302,
#  'statistics probability': 1684,
#  'probability theory': 1321,
#  'theory desire': 1783,
#  'desire leader': 515,
#  'leader background': 930,
#  'background systems': 168,
#  'systems spark': 1747,
#  'spark proficiency': 1642,
#  'proficiency sql': 1361,
#  'sql scripting': 1665,
#  'scripting language': 1571,
#  'language python': 918,
#  'python range': 1409,
#  'range modeling': 1443,
#  'modeling record': 1094,
#  'record goals': 1461,
#  'goals build': 745,
#  'build ship': 198,
#  'ship improvement': 1609,
#  'improvement network': 800,
#  'network partners': 1125,
#  'partners retailers': 1206,
#  'retailers pottery': 1537,
#  'pottery fulfillment': 1282,
#  'fulfillment consumer': 722,
#  'consumer access': 390,
#  'access offerings': 5,
#  'offerings stage': 1146,
#  'stage journey': 1667,
#  'journey installations': 886,
#  'installations assembly': 843,
#  'assembly maintenance': 115,
#  'maintenance owners': 976,
#  'owners proprietors': 1187,
#  'proprietors specialty': 1388,
#  'specialty areas': 1647,
#  'description': 511,
#  'support': 1716,
#  'judge': 888,
#  'questions': 1431,
#  'information': 816,
#  'bot': 189,
#  'responsibility': 1527,
#  'query': 1425,
#  'attention': 133,
#  'help': 776,
#  'guideline': 762,
#  'ambiguities': 68,
#  'description support': 513,
#  'support judge': 1718,
#  'judge questions': 889,
#  'questions information': 1433,
#  'information bot': 818,
#  'bot responsibility': 190,
#  'responsibility query': 1530,
#  'query attention': 1426,
#  'attention help': 136,
#  'help guideline': 777,
#  'guideline ambiguities': 763,
#  'ambiguities engineers': 69,
#  'assistance': 123,
#  'organization': 1167,
#  'software': 1616,
#  'fulfill': 719,
#  'requests': 1501,
#  'delivery': 492,
#  'documentation': 548,
#  'training': 1818,
#  'procedures': 1327,
#  'users': 1869,
#  'types': 1850,
#  'web': 1918,
#  'objectives': 1140,
#  'map': 1012,
#  'processes': 1337,
#  'usability': 1866,
#  'number': 1132,
#  'project': 1372,
#  'participant': 1195,
#  'updates': 1864,
#  'communicate': 306,
#  'system': 1730,
#  'enhancements': 613,
#  'modifications': 1097,
#  'managers': 989,
#  'sponsors': 1658,
#  'materials': 1035,
#  'guides': 767,
#  'trouble': 1842,
#  'phone': 1225,
#  'email': 582,
#  'communication': 308,
#  'duties': 560,
#  'self': 1585,
#  'supervisor': 1708,
#  'approval': 91,
#  'bachelors': 158,
#  'emphasis': 586,
#  'achievement': 15,
#  'database': 451,
#  'structures': 1696,
#  'theories': 1780,
#  'principles': 1311,
#  'knowledge': 900,
#  'issue': 883,
#  'privacy': 1316,
#  'practices': 1289,
#  'laws': 924,
#  'payment': 1215,
#  'card': 212,
#  'security': 1577,
#  'insurance': 850,
#  'portability': 1272,
#  'requirement': 1505,
#  'entry': 624,
#  'office': 1149,
#  'credibility': 431,
#  'material': 1033,
#  'queries': 1419,
#  'result': 1532,
#  'demands': 501,
#  'needs': 1110,
#  'assignments': 119,
#  'deadlines': 471,
#  'pressure': 1306,
#  'assistance organization': 126,
#  'organization maintenance': 1169,
#  'maintenance software': 977,
#  'software fulfill': 1625,
#  'fulfill requests': 720,
#  'requests software': 1503,
#  'software delivery': 1620,
#  'delivery improvement': 495,
#  'improvement software': 802,
#  'software documentation': 1621,
#  'documentation training': 551,
#  'training procedures': 1825,
#  'procedures training': 1331,
#  'training users': 1830,
#  'users types': 1873,
#  'types software': 1852,
#  'software web': 1628,
#  'web support': 1920,
#  'support objectives': 1720,
#  'objectives map': 1141,
#  'map processes': 1014,
#  'processes usability': 1342,
#  'usability systems': 1867,
#  'systems number': 1743,
#  'number project': 1133,
#  'project project': 1381,
#  'project participant': 1379,
#  'participant updates': 1196,
#  'updates management': 1865,
#  'management communicate': 979,
#  'communicate system': 307,
#  'system enhancements': 1732,
#  'enhancements modifications': 614,
#  'modifications documentation': 1098,
#  'documentation managers': 550,
#  'managers sponsors': 1000,
#  'sponsors training': 1659,
#  'training materials': 1824,
#  'materials guides': 1036,
#  'guides support': 768,
#  'support system': 1725,
#  'system trouble': 1735,
#  'trouble phone': 1843,
#  'phone email': 1226,
#  'email communication': 583,
#  'communication duties': 312,
#  'duties self': 563,
#  'self supervisor': 1592,
#  'supervisor approval': 1709,
#  'approval bachelors': 92,
#  'bachelors emphasis': 161,
#  'emphasis computer': 587,
#  'computer field': 354,
#  'field achievement': 679,
#  'achievement understanding': 16,
#  'understanding database': 1857,
#  'database structures': 455,
#  'structures theories': 1697,
#  'theories principles': 1781,
#  'principles knowledge': 1312,
#  'knowledge principles': 903,
#  'principles methodologies': 1313,
#  'methodologies issue': 1065,
#  'issue resolution': 884,
#  'resolution knowledge': 1511,
#  'knowledge privacy': 904,
#  'privacy practices': 1317,
#  'practices laws': 1290,
#  'laws payment': 925,
#  'payment card': 1216,
#  'card security': 213,
#  'security insurance': 1582,
#  'insurance portability': 851,
#  'portability requirement': 1273,
#  'requirement language': 1506,
#  'language attention': 913,
#  'attention entry': 134,
#  'entry office': 626,
#  'office software': 1150,
#  'procedures credibility': 1328,
#  'credibility material': 432,
#  'material queries': 1034,
#  'queries result': 1424,
#  'result demands': 1533,
#  'demands needs': 502,
#  'needs assignments': 1111,
#  'assignments deadlines': 120,
#  'deadlines pressure': 474,
#  'engine': 599,
#  'market': 1019,
#  'terms': 1772,
#  'intent': 862,
#  'engines': 611,
#  'machines': 971,
#  'guidelines': 764,
#  'lead': 927,
#  'assignment': 117,
#  'ambiguity': 71,
#  'errors': 635,
#  'review': 1538,
#  'checks': 247,
#  'speaker': 1644,
#  'road': 1551,
#  'names': 1105,
#  'places': 1244,
#  'maps': 1015,
#  'instructions': 846,
#  'judgements': 890,
#  'context': 397,
#  'searches': 1575,
#  'stores': 1688,
#  'schools': 1563,
#  'plus': 1259,
#  'problem': 1322,
#  'concise': 362,
#  'way': 1913,
#  'degradation': 482,
#  'aptitude': 96,
#  'description engine': 512,
#  'engine market': 600,
#  'market query': 1021,
#  'query terms': 1430,
#  'terms users': 1773,
#  'users intent': 1871,
#  'intent query': 863,
#  'query engines': 1428,
#  'engines machines': 612,
#  'machines users': 972,
#  'users map': 1872,
#  'map guidelines': 1013,
#  'guidelines query': 766,
#  'attention guideline': 135,
#  'ambiguities lead': 70,
#  'lead assignment': 928,
#  'assignment ambiguity': 118,
#  'ambiguity errors': 72,
#  'errors review': 636,
#  'review checks': 1539,
#  'checks query': 248,
#  'query communication': 1427,
#  'communication speaker': 317,
#  'speaker attention': 1645,
#  'attention road': 138,
#  'road names': 1552,
#  'names places': 1107,
#  'places names': 1245,
#  'names maps': 1106,
#  'maps understanding': 1016,
#  'understanding instructions': 1859,
#  'instructions judgements': 849,
#  'judgements context': 891,
#  'context project': 400,
#  'project searches': 1384,
#  'searches knowledge': 1576,
#  'knowledge stores': 906,
#  'stores schools': 1689,
#  'schools plus': 1564,
#  'plus problem': 1260,
#  'problem concise': 1324,
#  'concise way': 363,
#  'way web': 1914,
#  'web information': 1919,
#  'information guidelines': 823,
#  'guidelines efficiency': 765,
#  'efficiency degradation': 580,
#  'degradation aptitude': 483,
#  'aptitude software': 97,
#  'software office': 1626,
#  'title': 1797,
#  'summary': 1703,
#  'class': 257,
#  'publisher': 1401,
#  'portfolio': 1274,
#  'game': 735,
#  'franchises': 713,
#  'casino': 216,
#  'gummy': 769,
#  'solitaire': 1629,
#  'slots': 1614,
#  'cooking': 415,
#  'craze': 427,
#  'millions': 1069,
#  'day': 466,
#  'opportunity': 1151,
#  'connect': 371,
#  'compete': 340,
#  'device': 528,
#  'play': 1250,
#  'beliefs': 181,
#  'shares': 1601,
#  'challenge': 229,
#  'spirit': 1650,
#  'thrives': 1792,
#  'player': 1253,
#  'story': 1692,
#  'mentor': 1056,
#  'businesss': 202,
#  'decision': 476,
#  'telemetry': 1766,
#  'economy': 568,
#  'tuning': 1848,
#  'feature': 670,
#  'experimentation': 652,
#  'title summary': 1798,
#  'summary developer': 1704,
#  'developer world': 525,
#  'world class': 1939,
#  'class publisher': 258,
#  'publisher portfolio': 1402,
#  'portfolio game': 1275,
#  'game franchises': 736,
#  'franchises casino': 714,
#  'casino gummy': 217,
#  'gummy solitaire': 770,
#  'solitaire slots': 1630,
#  'slots cooking': 1615,
#  'cooking craze': 416,
#  'craze millions': 428,
#  'millions day': 1071,
#  'day opportunity': 470,
#  'opportunity connect': 1154,
#  'connect compete': 372,
#  'compete device': 341,
#  'device play': 529,
#  'play beliefs': 1251,
#  'beliefs shares': 182,
#  'shares challenge': 1602,
#  'challenge spirit': 230,
#  'spirit thrives': 1651,
#  'thrives player': 1793,
#  'player story': 1257,
#  'story mentor': 1693,
#  'mentor businesss': 1057,
#  'businesss decision': 203,
#  'decision game': 477,
#  'game player': 737,
#  'player telemetry': 1258,
#  'telemetry emphasis': 1767,
#  'emphasis economy': 588,
#  'economy tuning': 569,
#  'tuning feature': 1849,
#  'feature experimentation': 672,
#  'experimentation player': 653,
#  'monitoring': 1101,
#  'transportation': 1837,
#  'marquee': 1026,
#  'clients': 264,
#  'interface': 869,
#  'commuters': 336,
#  'consultant': 383,
#  'functions': 725,
#  'activities': 23,
#  'scope': 1565,
#  'compile': 344,
#  'analyze': 74,
#  'sources': 1635,
#  'collect': 283,
#  'rider': 1543,
#  'metrics': 1067,
#  'feedback': 674,
#  'ridership': 1545,
#  'coordination': 417,
#  'excellence': 646,
#  'maintain': 973,
#  'dashboards': 446,
#  'compliance': 348,
#  'member': 1052,
#  'blend': 187,
#  'entrepreneurship': 622,
#  'key': 896,
#  'brand': 193,
#  'competitors': 342,
#  'enthusiasm': 620,
#  'expectations': 649,
#  'box': 191,
#  'adaptability': 34,
#  'recommendations': 1454,
#  'ideas': 789,
#  'outcomes': 1172,
#  'face': 663,
#  'circumstances': 255,
#  'timelines': 1794,
#  'pressures': 1307,
#  'obstacles': 1142,
#  'communicator': 325,
#  'manner': 1001,
#  'target': 1761,
#  'audiences': 144,
#  'meetings': 1049,
#  'meeting': 1047,
#  'thinking': 1789,
#  'risks': 1549,
#  'contingency': 401,
#  'engagements': 597,
#  'creation': 429,
#  'landscape': 910,
#  'stories': 1690,
#  'numbers': 1135,
#  'spreadsheets': 1660,
#  'tables': 1759,
#  'charts': 241,
#  'formulas': 706,
#  'messages': 1060,
#  'relationships': 1472,
#  'approach': 88,
#  'managers monitoring': 995,
#  'monitoring transportation': 1102,
#  'transportation marquee': 1840,
#  'marquee clients': 1027,
#  'clients interface': 267,
#  'interface commuters': 870,
#  'commuters support': 337,
#  'support clients': 1717,
#  'clients transportation': 270,
#  'transportation consultant': 1838,
#  'consultant communication': 384,
#  'communication understanding': 318,
#  'understanding clients': 1854,
#  'clients management': 268,
#  'management functions': 981,
#  'functions project': 728,
#  'project activities': 1373,
#  'activities scope': 28,
#  'scope compile': 1567,
#  'compile analyze': 345,
#  'analyze sources': 75,
#  'sources clients': 1636,
#  'clients collect': 265,
#  'collect rider': 284,
#  'rider metrics': 1544,
#  'metrics feedback': 1068,
#  'feedback ridership': 675,
#  'ridership coordination': 1546,
#  'coordination training': 419,
#  'training excellence': 1821,
#  'excellence management': 647,
#  'management maintain': 982,
#  'maintain transportation': 974,
#  'transportation management': 1839,
#  'management software': 986,
#  'software dashboards': 1619,
#  'dashboards compliance': 447,
#  'compliance initiatives': 349,
#  'initiatives member': 835,
#  'member blend': 1053,
#  'blend entrepreneurship': 188,
#  'entrepreneurship key': 623,
#  'key brand': 897,
#  'brand clients': 194,
#  'clients competitors': 266,
#  'competitors enthusiasm': 343,
#  'enthusiasm clients': 621,
#  'clients needs': 269,
#  'needs expectations': 1112,
#  'expectations box': 650,
#  'box delivery': 192,
#  'delivery points': 497,
#  'points adaptability': 1264,
#  'adaptability recommendations': 35,
#  'recommendations ideas': 1456,
#  'ideas outcomes': 790,
#  'outcomes goals': 1174,
#  'goals face': 746,
#  'face circumstances': 664,
#  'circumstances timelines': 256,
#  'timelines pressures': 1795,
#  'pressures obstacles': 1308,
#  'obstacles information': 1143,
#  'information communicator': 819,
#  'communicator recommendations': 326,
#  'recommendations manner': 1459,
#  'manner target': 1005,
#  'target audiences': 1762,
#  'audiences information': 146,
#  'information project': 826,
#  'project meetings': 1378,
#  'meetings meeting': 1050,
#  'meeting thinking': 1048,
#  'thinking risks': 1790,
#  'risks contingency': 1550,
#  'contingency engagements': 402,
#  'engagements value': 598,
#  'value creation': 1882,
#  'creation context': 430,
#  'context market': 398,
#  'market landscape': 1020,
#  'landscape stories': 911,
#  'stories numbers': 1691,
#  'numbers spreadsheets': 1136,
#  'spreadsheets tables': 1661,
#  'tables charts': 1760,
#  'charts formulas': 242,
#  'formulas messages': 707,
#  'messages audience': 1061,
#  'audience relationships': 143,
#  'relationships approach': 1473,
#  'responsibilities': 1519,
#  'demand': 498,
#  'solution': 1631,
#  'subject': 1698,
#  'leadership': 934,
#  'reporting': 1486,
#  'goal': 740,
#  'lifecycle': 948,
#  'collection': 285,
#  'integration': 852,
#  'visualization': 1901,
#  'scale': 1558,
#  'process': 1332,
#  'leaders': 931,
#  'practitioners': 1292,
#  'action': 20,
#  'collaborate': 278,
#  'discovery': 539,
#  'model': 1083,
#  'running': 1554,
#  'predictions': 1296,
#  'patterns': 1211,
#  'framework': 710,
#  'productionize': 1353,
#  'alerting': 56,
#  'responsibilities demand': 1522,
#  'demand modeling': 500,
#  'modeling solution': 1095,
#  'solution delivery': 1632,
#  'delivery duties': 494,
#  'duties information': 561,
#  'information subject': 828,
#  'subject leadership': 1699,
#  'leadership information': 935,
#  'information improvement': 824,
#  'improvement processes': 801,
#  'processes reporting': 1340,
#  'reporting goal': 1487,
#  'goal improvement': 741,
#  'improvement areas': 799,
#  'areas lifecycle': 107,
#  'lifecycle collection': 949,
#  'collection mining': 288,
#  'mining integration': 1077,
#  'integration visualization': 854,
#  'visualization scale': 1903,
#  'scale sources': 1559,
#  'sources process': 1638,
#  'process systems': 1335,
#  'systems decision': 1740,
#  'decision support': 479,
#  'support leaders': 1719,
#  'leaders system': 932,
#  'system practitioners': 1733,
#  'practitioners action': 1293,
#  'action collaborate': 21,
#  'collaborate infrastructure': 279,
#  'infrastructure discovery': 832,
#  'discovery model': 540,
#  'model training': 1087,
#  'training running': 1826,
#  'running predictions': 1555,
#  'predictions patterns': 1297,
#  'patterns framework': 1212,
#  'framework self': 711,
#  'self manner': 1589,
#  'manner productionize': 1004,
#  'productionize processes': 1354,
#  'processes alerting': 1338,
#  'energy': 589,
#  'resources': 1512,
#  'diversity': 543,
#  'college': 292,
#  'planning': 1247,
#  'centers': 219,
#  'community': 331,
#  'innovation': 837,
#  'division': 545,
#  'enterprise': 617,
#  'registration': 1464,
#  'aid': 54,
#  'future': 734,
#  'efforts': 581,
#  'complexity': 347,
#  'structure': 1694,
#  'levels': 942,
#  'administration': 39,
#  'engineering': 602,
#  'depth': 510,
#  'owner': 1183,
#  'databases': 458,
#  'starter': 1670,
#  'priorities': 1314,
#  'abilities': 0,
#  'education': 575,
#  'qualifications': 1410,
#  'certification': 223,
#  'assurance': 130,
#  'space': 1640,
#  'use': 1868,
#  'hours': 786,
#  'interactions': 864,
#  'positions': 1276,
#  'completion': 346,
#  'evaluation': 639,
#  'authorization': 150,
#  'assessment': 116,
#  'experiences': 651,
#  'perspectives': 1224,
#  'project management': 1377,
#  'bachelors computer': 159,
#  'self starter': 1590,
#  'programming language': 1366,
#  'project deadlines': 1376,
#  'opportunity action': 1152,
#  'languages': 919,
#  'implementation': 797,
#  'brands': 195,
#  'traffic': 1817,
#  'content': 395,
#  'marketing': 1022,
#  'channels': 235,
#  'engagement': 596,
#  'prediction': 1294,
#  'amazons': 67,
#  'computing': 359,
#  'processing': 1343,
#  'challenges': 231,
#  'commerce': 303,
#  'mission': 1082,
#  'architecture': 100,
#  'edge': 572,
#  'track': 1807,
#  'approaches': 89,
#  'networks': 1128,
#  'fundamentals': 729,
#  'algorithm': 59,
#  'programming languages': 1367,
#  'communication audiences': 309,
#  'statistics field': 1678,
#  'track record': 1810,
#  'intelligence': 859,
#  'concepts': 360,
#  'features': 673,
#  'understanding statistics': 1863,
#  'statistics computer': 1677,
#  'economics': 566,
#  'presentation': 1302,
#  'video': 1890,
#  'benefit': 183,
#  'computer engineering': 353,
#  'coaching': 274,
#  'provideinformation': 1391,
#  'friend': 717,
#  'neighbor': 1117,
#  'kaleidoscope': 893,
#  'communitypartners': 334,
#  'additionalinformation': 37,
#  'tracking': 1811,
#  'thesesystems': 1786,
#  'improvements': 803,
#  'thequality': 1784,
#  'providetraining': 1399,
#  'media': 1044,
#  'line': 950,
#  'trackingsystems': 1815,
#  'funders': 732,
#  'contracts': 407,
#  'invoices': 879,
#  'accounting': 10,
#  'allaspects': 65,
#  'site': 1612,
#  'visits': 1899,
#  'arrangingfacility': 108,
#  'rentals': 1483,
#  'announcements': 80,
#  'registrations': 1466,
#  'documents': 553,
#  'packets': 1193,
#  'fees': 676,
#  'andarrange': 78,
#  'translation': 1835,
#  'curricula': 439,
#  'surveyincluding': 1726,
#  'forms': 704,
#  'surveys': 1728,
#  'reminders': 1479,
#  'reports': 1488,
#  'consultants': 385,
#  'processinvoices': 1344,
#  'supplies': 1712,
#  'requisitions': 1507,
#  'vendors': 1884,
#  'programoperations': 1370,
#  'needsof': 1115,
#  'families': 668,
#  'children': 250,
#  'contract': 403,
#  'deliverables': 489,
#  'projectsand': 1385,
#  'minimum': 1072,
#  'associatesdegree': 128,
#  'administrativesupport': 40,
#  'commitment': 304,
#  'toand': 1799,
#  'relevancy': 1475,
#  'humilityinclusion': 787,
#  'racism': 1435,
#  'communities': 327,
#  'color': 295,
#  'equity': 633,
#  'exploration': 657,
#  'power': 1283,
#  'privilege': 1318,
#  'formats': 701,
#  'person': 1222,
#  'discretion': 541,
#  'patience': 1209,
#  'etiquetteprofessionalism': 637,
#  'learners': 936,
#  'membersfunders': 1054,
#  'policymakers': 1268,
#  'sense': 1593,
#  'possibility': 1278,
#  'win': 1929,
#  'response': 1517,
#  'towork': 1805,
#  'state': 1672,
#  'king': 898,
#  'pierce': 1230,
#  'counties': 421,
#  'responsibilities provideinformation': 1525,
#  'provideinformation resources': 1392,
#  'resources friend': 1514,
#  'friend neighbor': 718,
#  'neighbor kaleidoscope': 1118,
#  'kaleidoscope phone': 894,
#  'email communitypartners': 584,
#  'communitypartners additionalinformation': 335,
#  'additionalinformation database': 38,
#  'database tracking': 457,
#  'tracking systems': 1814,
#  'systems thesesystems': 1749,
#  'thesesystems improvements': 1787,
#  'improvements challenges': 804,
#  'challenges thequality': 232,
#  'thequality collection': 1785,
#  'collection entry': 287,
#  'entry checks': 625,
#  'checks resources': 249,
#  'resources partners': 1516,
#  'partners information': 1203,
#  'information providetraining': 827,
#  'providetraining questions': 1400,
#  'questions collection': 1432,
#  'collection tracking': 291,
#  'systems media': 1742,
#  'media line': 1045,
#  'line trackingsystems': 953,
#  'trackingsystems funders': 1816,
#  'funders partners': 733,
#  'partners resources': 1205,
#  'resources information': 1515,
#  'information database': 820,
#  'systems track': 1750,
#  'track contracts': 1808,
#  'contracts invoices': 408,
#  'invoices coordination': 880,
#  'coordination resources': 418,
#  'resources accounting': 1513,
#  'accounting allaspects': 11,
#  'allaspects meetings': 66,
#  'meetings training': 1051,
#  'training site': 1827,
#  'site visits': 1613,
#  'visits arrangingfacility': 1900,
#  ...}

# %%
# Save

# %% [markdown]
# #### TF-IDF and NMF with Noun as token

# %%
# Model name: ***noun_tf_idf_NMF_1***
# Tokenizer: noun
# Vectorizer: TF-IDF
# Dimensionality reduction: LSA

tf_idf_vc_1 = TfidfVectorizer(ngram_range=(1, 2),
                            max_df = 0.9,
                            min_df = 0.005,
                            stop_words = stop_words_3
                             )

components = 15  # number of components
nmf_1 = NMF(components, random_state = 5)

topics = nmf_1.fit_transform(tf_idf_vc_1.fit_transform(jobs_skills_d.noun_skills).toarray())  # reduce dimensionality

print(len(tf_idf_vc_1.vocabulary_))   # number of words in dictionary

# pd.DataFrame(tf_idf_vc_1.fit_transform(jobs.noun).toarray(), columns=tf_idf_vc_1.get_feature_names()).head(10)

# lsa_1.components_
# tf_idf_vc_1.get_feature_names()

noun_tf_idf_NMF_1 = display_topics.topics_to_df(nmf_1, tf_idf_vc_1.get_feature_names(), 5, 'noun_tf_idf_NMF_1')  # save topics

pd.set_option('max_colwidth', 200)  # display strings
noun_tf_idf_NMF_1
# Out:
# 3029
#                                                                                  noun_tf_idf_NMF_1
# 0                                                home, porch, porch home, data science, experience
# 1                                        databricks, azure, data technologies, warehouse, database
# 2                                                         fish, fish games, games, player, players
# 3                                               client, program, clients, service, program manager
# 4                                            data fusion, fusion, search, analytics, fusion search
# 5                                   data business, processes, research, data analysis, improvement
# 6                            data guideline, questions information, bot user, bot, relevance judge
# 7                               splunk, customers, network, experience splunk, splunk environments
# 8                                      energy, candidates, accommodation, experience, applications
# 9                                                 ability, software, documentation, training, user
# 10                                                      entities, query, search, names, guidelines
# 11  sr data, pipelines recommendations, marketing solutions, content delivery, scientist marketing
# 12                             year, business analysis, product team, assurance, quality assurance
# 13                                                           home, porch, hands, teams, experience
# 14                                                     experience, skills, machine, staff, ability

# %%
# Save
columns=['LSA', 'NMF']
noun_topics = pd.concat([noun_tf_idf_LSA_1, noun_tf_idf_NMF_1], axis=1)

# %%
noun_topics
# Out:
#                                                                           noun_tf_idf_LSA_1  \
# 0                                        statistics, machine, modeling, techniques, results
# 1                                         warehouse, database, azure, databricks, pipelines
# 2                                      engineering, transportation, clients, water, traffic
# 3                                           player, game, visualization, sql, sql transform
# 4                                           cell, patients, medicine, cell therapy, therapy
# 5  clients, transportation, recommendations, businesses playerposition, clients competitors
# 6                                          platform, production, splunk, points, businesses
# 7                                                information, model, airlines, study, tools
# 8                                 query, entities, ambiguities engineers, holidayswe, judge
# 9                        building, project management, initiative, autocad, matching profit
#
#                                                                noun_tf_idf_NMF_1
# 0                         statistics, scalability, modeling, machine, techniques
# 1                              warehouse, database, databricks, azure, pipelines
# 2                            engineering, water, traffic, drawings, construction
# 3                               player, game, visualization, sql, techniques sql
# 4                                cell, patients, medicine, cell therapy, therapy
# 5       clients, transportation, recommendations, member blend, market landscape
# 6               platform, production, ididata, offerings capabilities, hood apps
# 7                                 model, machine, visualization, airlines, tools
# 8  query, entities, problem concise, information entities, guideline ambiguities
# 9                       clients, autocad, engineer, building, project management

# %% [markdown]
# #### LDA

# %%
from sklearn.decomposition import LatentDirichletAllocation 
from sklearn.datasets import make_multilabel_classification

lda = LatentDirichletAllocation(n_components=20, random_state=0)
topics = lda.fit_transform(tf_idf_vc_3.fit_transform(jobs_skills_d.noun_skills))

# %%
topics_to_df(lda, tf_idf_vc_3.get_feature_names(), 5, 'noun_LDA')
# Out:
#                                                                                    noun_LDA
# 0                                             product, energy, substitute, pne, experiments
# 1   description support, bot, questions information, judge questions, ambiguities engineers
# 2                              production, field background, prevention, enforcement, fraud
# 3                                                   player, game, feature, title, telemetry
# 4                       functionality, pals, pay pals, process understanding, payments site
# 5       investor, player communication, communication individual, sites, information scrape
# 6                                          difference, ideas, project, foundation, approach
# 7                 innovation, recommendation, guest, recommendation engines, millions users
# 8                                         databricks, azure, warehouse, database, pipelines
# 9                 clients, estate, management, version control, responsibilities management
# 10                      clients, transportation, chance, decisions clients, input decisions
# 11                                       dream, get, minute coaching, get minute, dream get
# 12                                         domain, instruction, title, description, thinker
# 13                                       machine, product, software, knowledge, engineering
# 14                                         modeling, statistics, products, machine, pottery
# 15                                 individuals, resumes, operation, accommodations, mission
# 16          product, product growth, cookies, algorithms pipelines, recommendations content
# 17                                       modeling, statistics, machine, professional, focus
# 18                                                 splunk, cookies, background, site, order
# 19                             suite, security, recruiting, authorization, laws regulations

# %%
tf_idf_vc_3 = TfidfVectorizer(ngram_range=(1, 2),
                            max_df = 0.4,
                            min_df = 0.005,
                            stop_words = stop_words_1
                             )

doc_word = tf_idf_vc_3.fit_transform(jobs_skills_d.noun_skills).transpose()
corpus = matutils.Sparse2Corpus(doc_word)
# Out:
# /Users/greenapple/anaconda3/envs/project4e/lib/python3.7/site-packages/sklearn/feature_extraction/text.py:300: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['bike', 'child', 'marketing', 'parking', 'views', 'waterfront'] not in stop_words.
#   'stop_words.' % sorted(inconsistent))

# %%
id2word = dict((v, k) for k, v in tf_idf_vc_3.vocabulary_.items())

# %%
lda = models.LdaModel(corpus=corpus, num_topics=15, id2word=id2word, passes=5)

# %%
lda.print_topics()
lda.
# Out:
# array([[1.77231959e-05, 1.77295078e-05, 1.77296224e-05, ...,
#         1.77848433e-05, 1.77495240e-05, 1.77231959e-05],
#        [3.46568273e-03, 4.16205767e-05, 4.16100156e-05, ...,
#         4.17433075e-05, 4.32481502e-05, 4.15648356e-05],
#        [4.46056481e-04, 4.46532998e-04, 4.46541701e-04, ...,
#         4.47016646e-04, 4.46056481e-04, 4.46056481e-04],
#        ...,
#        [1.77937818e-05, 1.77772836e-05, 1.77773745e-05, ...,
#         1.77716774e-05, 1.77716774e-05, 1.77716774e-05],
#        [1.74321103e-05, 1.01916936e-04, 1.73769386e-05, ...,
#         1.74026991e-05, 1.73706412e-05, 1.73815952e-05],
#        [1.27676640e-05, 1.27676640e-05, 1.27676640e-05, ...,
#         1.28802922e-05, 1.28060210e-05, 1.27676640e-05]], dtype=float32)

# %%
# topics_to_df(model, feature_names, no_top_words, model_name)
topics_to_df(lda, tf_idf_vc_3.get_feature_names(), 5, 'noun_tf_idf_LSA_1')  # save topics
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-89-a951834d4cb9> in <module>
#       1 # topics_to_df(model, feature_names, no_top_words, model_name)
# ----> 2 topics_to_df(lda, tf_idf_vc_3.get_feature_names(), 5, 'noun_tf_idf_LSA_1')  # save topics
#
# <ipython-input-88-610539ff65b1> in topics_to_df(model, feature_names, no_top_words, model_name)
#      10     words_list = []
#      11
# ---> 12     for ix, topic in enumerate(model.components_):
#      13         words = ", ".join([feature_names[i]for i in topic.argsort()[:-no_top_words - 1:-1]])
#      14         words_list.append(words)
#
# AttributeError: 'LdaModel' object has no attribute 'components_'

# %%
lda.print_topics()
# Out:
# [(0,
#   '0.026*"player" + 0.023*"game" + 0.012*"title" + 0.012*"economy" + 0.012*"thrives" + 0.012*"publisher" + 0.012*"device play" + 0.012*"experimentation player" + 0.012*"economy tuning" + 0.012*"feature experimentation"'),
#  (1,
#   '0.011*"tableau" + 0.010*"video" + 0.009*"college" + 0.008*"track record" + 0.008*"charlies" + 0.008*"identity orientation" + 0.008*"amazons" + 0.007*"economics" + 0.007*"leaders" + 0.007*"bachelors degree"'),
#  (2,
#   '0.044*"difference" + 0.026*"ideas" + 0.020*"project" + 0.007*"rate" + 0.005*"contract" + 0.004*"positions" + 0.001*"equity" + 0.001*"fortune" + 0.001*"culture" + 0.001*"colleagues"'),
#  (3,
#   '0.025*"splunk" + 0.010*"network" + 0.008*"payments" + 0.008*"provider" + 0.008*"providers" + 0.008*"concepts splunk" + 0.008*"splunk environments" + 0.008*"telecommunications" + 0.008*"connections" + 0.008*"certification"'),
#  (4,
#   '0.015*"processes" + 0.015*"improvement" + 0.011*"information" + 0.010*"model training" + 0.010*"predictions" + 0.010*"process systems" + 0.010*"productionize" + 0.010*"self manner" + 0.010*"responsibilities demand" + 0.010*"scale sources"'),
#  (5,
#   '0.034*"energy" + 0.010*"product" + 0.009*"call" + 0.009*"object programming" + 0.009*"intersection" + 0.009*"simulation" + 0.009*"minimum role" + 0.009*"opportunity individuals" + 0.009*"series" + 0.009*"kpi"'),
#  (6,
#   '0.015*"requirements" + 0.013*"product" + 0.010*"contract" + 0.009*"knowledge" + 0.009*"management" + 0.008*"testing" + 0.008*"project" + 0.008*"responsibilities" + 0.007*"engineering" + 0.007*"machine"'),
#  (7,
#   '0.013*"director" + 0.012*"future" + 0.010*"media" + 0.010*"innovation" + 0.007*"leadership" + 0.006*"engagement" + 0.006*"growth" + 0.005*"mission" + 0.004*"way" + 0.004*"individuals"'),
#  (8,
#   '0.018*"platform" + 0.013*"production" + 0.010*"fraud" + 0.010*"production code" + 0.010*"fraud detection" + 0.010*"machine statistics" + 0.009*"physics field" + 0.009*"computer machine" + 0.009*"field background" + 0.009*"bash"'),
#  (9,
#   '0.016*"clients" + 0.008*"transportation" + 0.007*"modeling" + 0.007*"statistics" + 0.005*"products" + 0.005*"initiatives" + 0.005*"management" + 0.005*"audience" + 0.004*"recommendations" + 0.004*"machine"'),
#  (10,
#   '0.074*"hundreds" + 0.067*"coaching" + 0.055*"tech" + 0.027*"role" + 0.027*"internet" + 0.025*"requirements" + 0.024*"platform" + 0.023*"level" + 0.010*"recruiting" + 0.005*"maps"'),
#  (11,
#   '0.015*"agency" + 0.012*"project" + 0.009*"managers" + 0.008*"range" + 0.008*"neighborhood" + 0.007*"security" + 0.007*"day" + 0.007*"training" + 0.006*"activities" + 0.006*"understanding"'),
#  (12,
#   '0.023*"query" + 0.020*"description support" + 0.020*"support judge" + 0.020*"information bot" + 0.020*"judge questions" + 0.020*"questions information" + 0.020*"help guideline" + 0.020*"bot" + 0.020*"ambiguities engineers" + 0.020*"bot responsibility"'),
#  (13,
#   '0.031*"azure" + 0.031*"databricks" + 0.030*"warehouse" + 0.026*"database" + 0.022*"pipelines" + 0.016*"azure databricks" + 0.016*"visas" + 0.016*"functions database" + 0.016*"bigdata mart" + 0.016*"mart bachelors"'),
#  (14,
#   '0.013*"modeling" + 0.013*"statistics" + 0.009*"machine" + 0.007*"professional" + 0.007*"areas focus" + 0.007*"focus stage" + 0.007*"move" + 0.007*"marketplace goal" + 0.007*"owners specialty" + 0.007*"overstock bay"')]

# %%
lda_corpus = lda[corpus]
lda_corpus

# %%
lda_docs = [doc for doc in lda_corpus]

# %%
lda_docs[:10]
# Out:
# [[(8, 0.9177795)],
#  [(9, 0.9297521)],
#  [(0, 0.011232609),
#   (1, 0.011232609),
#   (2, 0.011232609),
#   (3, 0.011232609),
#   (4, 0.011232611),
#   (5, 0.011232609),
#   (6, 0.011232611),
#   (7, 0.011232609),
#   (8, 0.011232609),
#   (9, 0.011232609),
#   (10, 0.011232609),
#   (11, 0.011232609),
#   (12, 0.84274346),
#   (13, 0.011232611),
#   (14, 0.011232609)],
#  [(0, 0.01123261),
#   (1, 0.01123261),
#   (2, 0.01123261),
#   (3, 0.01123261),
#   (4, 0.011232612),
#   (5, 0.01123261),
#   (6, 0.011232612),
#   (7, 0.01123261),
#   (8, 0.01123261),
#   (9, 0.01123261),
#   (10, 0.01123261),
#   (11, 0.01123261),
#   (12, 0.84274346),
#   (13, 0.011232612),
#   (14, 0.01123261)],
#  [(12, 0.9301613)],
#  [(12, 0.9117793)],
#  [(8, 0.9177795)],
#  [(12, 0.9301613)],
#  [(0, 0.9055725)],
#  [(12, 0.93016124)]]

# %%
len(lda_docs)
# Out:
# 5058

# %%
len(lda.top_topics(corpus))
# get_topic_terms()
# Out:
# 15

# %% [markdown]
# ### Lemma as a token

# %% [markdown]
# #### TF-IDF and LSA

# %%
# Model name: ***lemma_tf_idf_LSA_1***
# Tokenizer: noun
# Vectorizer: TF-IDF
# Dimensionality reduction: LSA

tf_idf_vc_2 = TfidfVectorizer(ngram_range=(1, 2),
                            max_df = 0.5,
                            min_df = 0.005,
                            stop_words = stop_words_1)   

components = 10  # number of LSA components
lsa_2 = TruncatedSVD(components, random_state = 5, algorithm='arpack')


topics = lsa_2.fit_transform(tf_idf_vc_2.fit_transform(jobs_skills_d.lemma_skills).toarray())  # reduce dimensionality

print(len(tf_idf_vc_2.vocabulary_))   # number of words in dictionary
print(lsa_2.explained_variance_ratio_)      # explained variance

# pd.DataFrame(tf_idf_vc_1.fit_transform(jobs.noun).toarray(), columns=tf_idf_vc_1.get_feature_names()).head(10)

# lsa_1.components_
# tf_idf_vc_1.get_feature_names()

lemma_tf_idf_LSA = display_topics.topics_to_df(lsa_2, tf_idf_vc_2.get_feature_names(), 5, 'lemma_tf_idf_LSA')  # save topics

pd.set_option('max_colwidth', 200)  # display strings
lemma_tf_idf_LSA
# Out:
# /Users/greenapple/anaconda3/envs/project4e/lib/python3.7/site-packages/sklearn/feature_extraction/text.py:300: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['bike', 'marketing', 'parking', 'views', 'waterfront'] not in stop_words.
#   'stop_words.' % sorted(inconsistent))
# 6183
# [0.0261766  0.06066876 0.05554731 0.04088264 0.04218492 0.03853903
#  0.03630052 0.03504401 0.03407754 0.03308529]
#                                                        lemma_tf_idf_LSA
# 0                        technical, product, broad, modeling, statistic
# 1                      dream, match, see, opportunity reflect, see find
# 2                       big, mart report, create mart, xcell, databrick
# 3                     technical, broad, xcell, mart report, create mart
# 4                                     game, player, big game, big, play
# 5                      product, insight, use cookie, cookie, background
# 6                         trans west, trans, west, plan, transportation
# 7                            enable, improvement, process, drive, model
# 8                chance, raybeam, input decision, input, analytic space
# 9  judge, guideline, attention help, responsibility judge, good respond

# %% [markdown]
# ### Word as a token

# %%
jobs_skills_d.columns
# Out:
# Index(['company_name', 'description', 'job_title', 'link', 'location',
#        'salary', 'state', 'type', 'sentences', 'start_stop', 'skills',
#        'clean_skills', 'noun_skills', 'word_skills', 'noun_lemma_skills',
#        'lemma_skills'],
#       dtype='object')

# %%
# Model name: ***lemma_tf_idf_LSA_1***
# Tokenizer: noun
# Vectorizer: TF-IDF
# Dimensionality reduction: LSA

tf_idf_vc_3 = TfidfVectorizer(ngram_range=(1, 2),
                            max_df = 0.9,
                            min_df = 0.005,
                            stop_words = stop_words_1)   

components = 20  # number of LSA components
lsa_3 = TruncatedSVD(components, random_state = 5, algorithm='arpack')


topics = lsa_3.fit_transform(tf_idf_vc_3.fit_transform(jobs_skills_d.word_skills).toarray())  # reduce dimensionality

print(len(tf_idf_vc_3.vocabulary_))   # number of words in dictionary
print(lsa_3.explained_variance_ratio_)      # explained variance

# pd.DataFrame(tf_idf_vc_1.fit_transform(jobs.noun).toarray(), columns=tf_idf_vc_1.get_feature_names()).head(10)

# lsa_1.components_
# tf_idf_vc_1.get_feature_names()

word_tf_idf_LSA = display_topics.topics_to_df(lsa_3, tf_idf_vc_3.get_feature_names(), 5, 'word_tf_idf_LSA')  # save topics

pd.set_option('max_colwidth', 200)  # display strings
word_tf_idf_LSA
# Out:
# /Users/greenapple/anaconda3/envs/project4e/lib/python3.7/site-packages/sklearn/feature_extraction/text.py:300: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['bike', 'marketing', 'parking', 'views', 'waterfront'] not in stop_words.
#   'stop_words.' % sorted(inconsistent))
# 6443
# [0.02901999 0.06142611 0.0550139  0.03761644 0.04184797 0.03833059
#  0.0361111  0.03529477 0.03459653 0.03223125 0.03144761 0.03078089
#  0.03061195 0.03026043 0.02939985 0.0247395  0.02504362 0.02446989
#  0.02359842 0.02223259]
#                                                                          word_tf_idf_LSA
# 0                                         technical, modeling, broad, strong, statistics
# 1                                   seen, dream, coaching, started minute, coaching sure
# 2                                          big, reports, mart reports, xcell, databricks
# 3                                                product, clients, develop, player, plus
# 4                                                     game, player, big, play, dedicated
# 5                                           product, cookies, site, background, analyses
# 6                                 red, proprietary, distributed, idi, highly distributed
# 7                                            enable, driven, improvement, processes, key
# 8                             chance, raybeam, input decisions, decisions clients, input
# 9                judge, prepare good, respond guideline, support judge, responsible read
# 10                                                 splunk, payments, secure, pay, global
# 11                                          pay, product, gain, deep understanding, deep
# 12                                  growth, periscope, recommendations, tableau, product
# 13  individuals, understand benefit, help access, benefit human, accommodations extandme
# 14                                           periscope, pay, growth, tableau, actionable
# 15                                           cbre, innovation, real estate, estate, real
# 16              innovation, recommendation, digital, digital innovation, push boundaries
# 17                                           cloud, insurance, long, innovative, applied
# 18            cbre, commissioning, clients, clients commissioning, electronic management
# 19                                       energy, prefer, linear, forecasting, reasonable

# %% [markdown]
# ### Noun-lemma as a token

# %%
jobs_skills_d.columns
# Out:
# Index(['company_name', 'description', 'job_title', 'link', 'location',
#        'salary', 'state', 'type', 'sentences', 'start_stop', 'skills',
#        'clean_skills', 'noun_skills', 'word_skills', 'noun_lemma_skills',
#        'lemma_skills'],
#       dtype='object')

# %%
# Model name: ***lemma_tf_idf_LSA_1***
# Tokenizer: noun
# Vectorizer: TF-IDF
# Dimensionality reduction: LSA

tf_idf_vc_4 = TfidfVectorizer(ngram_range=(1, 2),
                            max_df = 0.8,
                            min_df = 0.005,
                            stop_words = stop_words_1)   

components = 15  # number of LSA components
lsa_4 = TruncatedSVD(components, random_state = 5, algorithm='arpack')


topics = lsa_4.fit_transform(tf_idf_vc_4.fit_transform(jobs_skills_d.noun_lemma_skills).toarray())  # reduce dimensionality

print(len(tf_idf_vc_4.vocabulary_))   # number of words in dictionary
print(lsa_4.explained_variance_ratio_)      # explained variance

# pd.DataFrame(tf_idf_vc_1.fit_transform(jobs.noun).toarray(), columns=tf_idf_vc_1.get_feature_names()).head(10)

# lsa_1.components_
# tf_idf_vc_1.get_feature_names()

noun_lemma_tf_idf_LSA = display_topics.topics_to_df(lsa_4, tf_idf_vc_4.get_feature_names(), 5, 'noun_lemma_tf_idf_LSA')  # save topics

pd.set_option('max_colwidth', 200)  # display strings
noun_lemma_tf_idf_LSA
# Out:
# /Users/greenapple/anaconda3/envs/project4e/lib/python3.7/site-packages/sklearn/feature_extraction/text.py:300: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['bike', 'marketing', 'parking', 'views', 'waterfront'] not in stop_words.
#   'stop_words.' % sorted(inconsistent))
# 2953
# [0.02639784 0.06077751 0.05537872 0.04153569 0.04265306 0.03903482
#  0.03708041 0.03556091 0.03443994 0.03295311 0.03190539 0.0308505
#  0.03057664 0.02932024 0.02928668]
#                                                                noun_lemma_tf_idf_LSA
# 0                                       product, modeling, statistic, project, model
# 1                    dream, dream requirement, minute hundred, get minute, dream get
# 2                                    databrick, azure, warehouse, pipeline, database
# 3                                 modeling, professional, databrick, azure, pipeline
# 4                       game, player, game developer, game franchise, insight player
# 5                                    product, insight, cookie, site, insight product
# 6                                transportation, product, plan, information, insight
# 7                                   process, improvement, model, information, system
# 8    production, innovation, flexibility opportunity, table tennis, problem identity
# 9   guideline, information bot, help guideline, responsibility query, attention help
# 10                            splunk, provider, connection, certification, community
# 11                                      individual, law, sql, information, operation
# 12           pal, pay pal, functionality leadership, combination acuman, insight pay
# 13                       individual, mission, visualization, substitute teacher, pne
# 14              growth insight, growth, market hub, physics analytic, table bachelor

# %% [markdown]
# ### Stop words

# %%
stop_words_1 = [
    'yearexperience', 'year', 'years', 'porch', 'work', 'home', 'term', 'datum', 'hand', 'science', 'other', 
    're', 'sex', 'gender', 'data scientist', 'data scientists', 'scientists','scientist', 'com', 'age', 
    'analyst', 'analysts', 'race','hourexperience', 'job type', 'end', 'employee', 'employees','employers', 
    'employer', 'job', 'career', 'fish', 'violet','opportunities', 'business', 'disability', 'company', 
    'companies', 'stakeholders', 'talent', 'skill', 'skills', 'team', 'teams', 'experience', 'expert', 'hands', 
    'games', 'players', 'creativity','models', 'roles', 'application', 'specifications', 'change','issues', 
    'search', 'status', 'impact', 'changes', 'location', 'detail', 'insights', 'document', 'client', 'sets', 
    'set', 'detail', 'analytics', 'fusion','applications', 'candidates','standards', 'manager', 'assets', 
    'health', 'accommodation', 'services', 'service', 'transwest', 'program', 'commute', 'utilization',
    'technology', 'solutions', 'part', 'success', 'findings', 'notes', 'satisfaction', 'case', 'group', 'redviolet', 'trends', 'optimization',
    'others', 'account', 'strategy', 'bike parking', 'account', 'performance','preduction', 'relationship', 
    'waterfront views', 'manage', 'quality', 'type time', 'problems', 'projects', 'people', 'collaboration', 
    'strategies', 'programs', 'partner', 'core', 'operations', 'rsu', 'plans', 'methods', 'variety', 'revenue', 
    'data', 'technologies', 'visualizations', 'type', 'life', 'safety', 'analysis', 'time', 'design', 'research', 
    'relevance', 'passion', 'customer', 'learning', 'environment', 'tasks','family', 'benefits', 'development', 
    'complete', 'industry', 'user', 'organizations', 'customers', 'documentations', 'members', 'competencies',
    'homeowners', 'networking', 'apply', 'hire', 'homeowner', 'jobs', 'firm', 'position', 'entities',
    'tools', 'initiative', 'servicekey', 'intents', 'merit','bonuses', 'paid', 'asset', 'candidate', 
    'building', 'sector', 'employment', 'stakeholder', 'note', 'entity', 'finding', 'staff', 'drawing',
    'award', 'tool', 'latitude', 'view', 'button', 'matter', 'method', 'professionals', 'techniques',
    'states', 'house', 'holidayswe', 'handyman', 'requirementsperform', 'sr', 'sales', 'results',
    'length', 'ability', 'expertise', 'sr marketing', 'interviewdirectenergy', 'parks', 'child care',
    'religion', 'veteran', 'regard', 'days', 'directors', 'topics', 'salary', 'interview', 'care',
    'repairs', 'carpentry', 'role', 'tech', 'hundreds', 'requirements', 'platform', 'level', 'child',
    'orientation', 'growth', 'product', 'products'
]

# %%
stop_words_2 = [
    'yearexperience', 'year', 'porch', 'work', 'home', 'term', 'datum', 'hand', 'science', 'other', 
    're', 'sex', 'gender', 'data scientist', 'scientist', 'com', 'age', 
    'analyst', 'race','hourexperience', 'job type', 'end', 'employee',
    'employer', 'job', 'career', 'fish', 'violet','opportunity', 'business', 'disability', 'company', 
    'stakeholders', 'talent', 'skill', 'team', 'experience', 'expert', 
    'player', 'creativity', 'role', 'application', 'specification', 'change','issue', 
    'search', 'status', 'impact', 'changes', 'location', 'detail', 'insight', 'document', 'client',
    'set', 'detail', 'analytics', 'fusion','applications', 'candidates','standards', 'manager', 'asset', 
    'health', 'accommodation', 'service', 'transwest', 'program', 'commute', 'utilization',
    'technology', 'solution', 'part', 'success', 'finding', 'satisfaction', 'case', 'group', 'redviolet', 'trends', 'optimization',
    'account', 'strategy', 'bike parking', 'account', 'performance','preduction', 'relationship', 
    'waterfront view', 'manage', 'quality', 'type time', 'people', 'collaboration', 
    'partner', 'core', 'variety', 'revenue', 
    'data', 'type', 'life', 'safety', 'analysis', 'time', 'design', 'research', 
    'relevance', 'passion', 'customer', 'learning', 'environment', 'task','family', 'benefit', 'development', 
    'complete', 'industry', 'day', 'sector'
]

# %%
stop_words_3 = []

# %% [markdown]
# ## Functions

# %%
# %%writefile '/Users/greenapple/project4/src/models/display_topics.py'

import pandas as pd

def topics_to_df(model, feature_names, no_top_words, model_name):
    '''
    Add topic words for dimensionality reduction to dataframe.
    '''
    df = pd.DataFrame()
    words_list = []
    
    for ix, topic in enumerate(model.components_):
        words = ", ".join([feature_names[i]for i in topic.argsort()[:-no_top_words - 1:-1]])
        words_list.append(words)
    
    df[model_name] = pd.Series(words_list)
     
    return df
